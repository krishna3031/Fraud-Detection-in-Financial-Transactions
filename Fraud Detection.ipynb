# %%
# ==========================
# FRAUD DETECTION PROJECT
# Isolation Forest Model
# ==========================

# Import Libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, confusion_matrix

# ==========================
# Load Dataset
# ==========================

df = pd.read_csv("creditcard.csv")

print("Dataset Shape:", df.shape)
print(df.head())

# ==========================
# Feature & Target Split
# ==========================

X = df.drop("Class", axis=1)
y = df["Class"]

# ==========================
# Feature Scaling
# ==========================

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# ==========================
# Train-Test Split
# ==========================

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# ==========================
# Isolation Forest Model
# ==========================

model = IsolationForest(
    n_estimators=100,
    contamination=0.0017,  # Fraud percentage
    random_state=42
)

model.fit(X_train)

# ==========================
# Predictions
# ==========================

pred = model.predict(X_test)

# Isolation Forest Output:
# 1  = Normal
# -1 = Anomaly

pred = np.where(pred == -1, 1, 0)

# ==========================
# Evaluation
# ==========================

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, pred))

print("\nClassification Report:")
print(classification_report(y_test, pred))
# Out:
# Dataset Shape: (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]
#
# Confusion Matrix:
# [[56791    73]
#  [   65    33]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.31      0.34      0.32        98
#
#     accuracy                           1.00     56962
#    macro avg       0.66      0.67      0.66     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
import joblib

joblib.dump(model, "fraud_detection_model.pkl")
joblib.dump(scaler, "scaler.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
import joblib
import numpy as np

model = joblib.load("fraud_detection_model.pkl")
scaler = joblib.load("scaler.pkl")

new_transaction = np.array([
    [1000, 0.5, -1.2, 0.3, 0.8, -0.2, 0.1,
     0.4, -0.3, 1.1, 0.7, -0.4, 0.2, 0.5,
     -0.8, 0.9, -0.6, 0.1, 0.3, -0.5,
     0.2, 0.4, -0.7, 0.6, -0.1, 0.8,
     -0.4, 0.5,250]
])

new_transaction = scaler.transform(new_transaction)

prediction = model.predict(new_transaction)

if prediction[0] == -1:
    print("⚠️ Fraud Alert")
else:
    print("✅ Legitimate Transaction")
# Out:
# C:\Users\naiti\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 15
#       5 scaler = joblib.load("scaler.pkl")
#       7 new_transaction = np.array([
#       8     [1000, 0.5, -1.2, 0.3, 0.8, -0.2, 0.1,
#       9      0.4, -0.3, 1.1, 0.7, -0.4, 0.2, 0.5,
#    (...)     12      -0.4, 0.5,250]
#      13 ])
# ---> 15 new_transaction = scaler.transform(new_transaction)
#      17 prediction = model.predict(new_transaction)
#      19 if prediction[0] == -1:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_data.py:1094, in StandardScaler.transform(self, X, copy)
#    1091 check_is_fitted(self)
#    1093 copy = copy if copy is not None else self.copy
# -> 1094 X = validate_data(
#    1095     self,
#    1096     X,
#    1097     reset=False,
#    1098     accept_sparse="csr",
#    1099     copy=copy,
#    1100     dtype=supported_float_dtypes(xp, X_device),
#    1101     force_writeable=True,
#    1102     ensure_all_finite="allow-nan",
#    1103 )
#    1105 if sparse.issparse(X):
#    1106     if self.with_mean:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2923, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2923     _check_n_features(_estimator, X, reset=reset)
#    2925 return out
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_n_features(estimator, X, reset)
#    2784     return
#    2786 if n_features != estimator.n_features_in_:
# -> 2787     raise ValueError(
#    2788         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2789         f"is expecting {estimator.n_features_in_} features as input."
#    2790     )
#
# ValueError: X has 29 features, but StandardScaler is expecting 30 features as input.

# %%
print(scaler.n_features_in_)
# Out:
# 30
